# %%
import numpy as np
import joblib
from ipynb.fs.full.Common import evaluate

# %%
# load models

model_dectree = joblib.load('spam_decisiontree.joblib')
model_knn = joblib.load('spam_knn.joblib')
model_logreg = joblib.load('spam_logreg.joblib')
model_naivebayes = joblib.load('spam_naivebayes.joblib')
model_svm = joblib.load('spam_svm.joblib')
model_mlp = joblib.load('spam_mlp.joblib')

# %%
# Load testing data

loaded = np.load('spam_data.npz', allow_pickle=True)
X_test = loaded['Xtest']
y_test = loaded['ytest']

# %%
# Evaluation Decision Tree

pred_dectree = model_dectree.predict(X_test)
evaluate(y_test, pred_dectree, "Decision Tree")
# Out:
# Accuracy: 0.967118
# Precision: 0.919355
# Recall: 0.826087
# F1 score: 0.870229

# %%
# Evaluation KNN

pred_knn = model_knn.predict(X_test)
evaluate(y_test, pred_knn, 'K Nearest Neighbours')
# Out:
# Accuracy: 0.880077
# Precision: 1.000000
# Recall: 0.101449
# F1 score: 0.184211

# %%
# Evaluation logistic Regression

pred_logreg = model_logreg.predict(X_test)
evaluate(y_test, pred_logreg, 'Logistic Regression')
# Out:
# Accuracy: 0.980658
# Precision: 0.975806
# Recall: 0.876812
# F1 score: 0.923664

# %%
# Evaluation Naive Bayes

pred_nb = model_naivebayes.predict(X_test)
evaluate(y_test, pred_nb, 'Naive Bayes')
# Out:
# Accuracy: 0.964217
# Precision: 0.813665
# Recall: 0.949275
# F1 score: 0.876254

# %%
# Evaluation SVM

pred_svm = model_svm.predict(X_test)
evaluate(y_test, pred_svm, 'Support Vector Machine')
# Out:
# Accuracy: 0.971954
# Precision: 0.990991
# Recall: 0.797101
# F1 score: 0.883534

# %%
# Evaluation MLP Neural Network

pred_mlp = model_mlp.predict(X_test)
evaluate(y_test, pred_mlp, 'MLP Neural Network')
# Out:
# Accuracy: 0.981625
# Precision: 0.968504
# Recall: 0.891304
# F1 score: 0.928302
