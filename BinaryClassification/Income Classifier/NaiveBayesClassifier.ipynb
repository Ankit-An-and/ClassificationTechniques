# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB
import joblib

# %%
# Read data

loaded = np.load('adult_income_data.npz', allow_pickle=True)

# Split Data

X_train = loaded['Xtrain']
X_test = loaded['Xtest']
y_train = loaded['ytrain']
y_test = loaded['ytest']

# %%
# Naive Bayes Classifier

model = MultinomialNB().fit(X_train, y_train)

# %%
# Evaluation
evaluate(y_test, pred, df, "Naive Bayes")
# Out:
# Accuracy: 0.779380
# Precision: 0.677007
# Recall: 0.243279
# F1 score: 0.357935
