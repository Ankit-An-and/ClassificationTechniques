# %%
import numpy as np
import joblib
from ipynb.fs.full.Common import evaluate

# %%
# load models

model_dectree = joblib.load('tweet_dectree.joblib')
model_knn = joblib.load('tweet_knn.joblib')
model_rf = joblib.load('tweet_rf.joblib')
model_mlp = joblib.load('tweet_mlp.joblib')
model_naivebayes = joblib.load('tweet_naivebayes.joblib')

# %%
# Load testing data

loaded = np.load('tweet_data.npz', allow_pickle=True)
X_test = loaded['Xtest']
y_test = loaded['ytest']

# %%
# Evaluation Decision Tree

pred_dectree = model_dectree.predict(X_test)
evaluate(y_test, pred_dectree, "Decision Tree")
# Out:
# Accuracy: 0.611111
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.596     0.555     0.574       595
#            1      0.602     0.687     0.642       597
#            2      0.637     0.592     0.614       608
#
#     accuracy                          0.611      1800
#    macro avg      0.612     0.611     0.610      1800
# weighted avg      0.612     0.611     0.610      1800

# %%
# Evaluation KNN

pred_knn = model_knn.predict(X_test)
evaluate(y_test, pred_knn, 'K Nearest Neighbours')
# Out:
# Accuracy: 0.371667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.676     0.123     0.208       595
#            1      0.343     0.955     0.505       597
#            2      0.839     0.043     0.081       608
#
#     accuracy                          0.372      1800
#    macro avg      0.619     0.373     0.265      1800
# weighted avg      0.621     0.372     0.264      1800

# %%
# Evaluation Random Forest

pred_rf = model_rf.predict(X_test)
evaluate(y_test, pred_rf, 'Random Forest')
# Out:
# Accuracy: 0.653333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.749     0.516     0.611       595
#            1      0.560     0.893     0.688       597
#            2      0.767     0.553     0.642       608
#
#     accuracy                          0.653      1800
#    macro avg      0.692     0.654     0.647      1800
# weighted avg      0.692     0.653     0.647      1800

# %%
# Evaluation Naive Bayes

pred_nb = model_naivebayes.predict(X_test)
evaluate(y_test, pred_nb, 'Naive Bayes')
# Out:
# Accuracy: 0.630556
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.600     0.692     0.643       595
#            1      0.653     0.570     0.608       597
#            2      0.647     0.630     0.638       608
#
#     accuracy                          0.631      1800
#    macro avg      0.633     0.631     0.630      1800
# weighted avg      0.633     0.631     0.630      1800

# %%
# Evaluation MLP Neural Network

pred_mlp = model_mlp.predict(X_test)
evaluate(y_test, pred_mlp, 'MLP Neural Network')
# Out:
# Accuracy: 0.620000
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.604     0.624     0.614       595
#            1      0.654     0.601     0.627       597
#            2      0.606     0.635     0.620       608
#
#     accuracy                          0.620      1800
#    macro avg      0.621     0.620     0.620      1800
# weighted avg      0.621     0.620     0.620      1800
