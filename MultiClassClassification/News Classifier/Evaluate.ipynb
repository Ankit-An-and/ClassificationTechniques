# %%
import numpy as np
import joblib
from ipynb.fs.full.Common import evaluate

# %%
# load models

model_dectree = joblib.load('news_dectree.joblib')
model_knn = joblib.load('news_knn.joblib')
model_rf = joblib.load('news_rf.joblib')
model_naivebayes = joblib.load('news_naivebayes.joblib')
model_mlp = joblib.load('news_mlp.joblib')

# %%
# Load testing data

loaded = np.load('news_data.npz', allow_pickle=True)
X_test = loaded['Xtest']
y_test = loaded['ytest']

# %%
# Evaluation Decision Tree

pred_dectree = model_dectree.predict(X_test)
evaluate(y_test, pred_dectree, "Decision Tree")
# Out:
# Accuracy: 0.791080
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.800     0.816     0.808       103
#            1      0.773     0.784     0.779        74
#            2      0.782     0.753     0.767        81
#            3      0.879     0.879     0.879        91
#            4      0.701     0.701     0.701        77
#
#     accuracy                          0.791       426
#    macro avg      0.787     0.787     0.787       426
# weighted avg      0.791     0.791     0.791       426

# %%
# Evaluation KNN

pred_knn = model_knn.predict(X_test)
evaluate(y_test, pred_knn, 'K Nearest Neighbours')
# Out:
# Accuracy: 0.971831
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.971     0.961     0.966       103
#            1      1.000     0.932     0.965        74
#            2      0.931     1.000     0.964        81
#            3      1.000     1.000     1.000        91
#            4      0.961     0.961     0.961        77
#
#     accuracy                          0.972       426
#    macro avg      0.973     0.971     0.971       426
# weighted avg      0.973     0.972     0.972       426

# %%
# Evaluation Random Forest

pred_rf = model_rf.predict(X_test)
evaluate(y_test, pred_rf, 'Random Forest')
# Out:
# Accuracy: 0.845070
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.773     0.961     0.857       103
#            1      1.000     0.622     0.767        74
#            2      0.971     0.815     0.886        81
#            3      0.734     1.000     0.847        91
#            4      0.967     0.753     0.847        77
#
#     accuracy                          0.845       426
#    macro avg      0.889     0.830     0.841       426
# weighted avg      0.877     0.845     0.843       426

# %%
# Evaluation Naive Bayes

pred_nb = model_naivebayes.predict(X_test)
evaluate(y_test, pred_nb, 'Naive Bayes')
# Out:
# Accuracy: 0.962441
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.935     0.981     0.957       103
#            1      1.000     0.905     0.950        74
#            2      0.929     0.975     0.952        81
#            3      0.989     1.000     0.995        91
#            4      0.973     0.935     0.954        77
#
#     accuracy                          0.962       426
#    macro avg      0.965     0.959     0.962       426
# weighted avg      0.964     0.962     0.962       426

# %%
# Evaluation MLP Neural Network

pred_mlp = model_mlp.predict(X_test)
evaluate(y_test, pred_mlp, 'MLP Neural Network')
# Out:
# Accuracy: 0.969484
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.961     0.961     0.961       103
#            1      0.986     0.946     0.966        74
#            2      0.930     0.988     0.958        81
#            3      1.000     1.000     1.000        91
#            4      0.973     0.948     0.961        77
#
#     accuracy                          0.969       426
#    macro avg      0.970     0.969     0.969       426
# weighted avg      0.970     0.969     0.970       426
